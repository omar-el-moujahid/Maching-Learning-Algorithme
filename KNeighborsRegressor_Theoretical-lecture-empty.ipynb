# %% [markdown]
# # K-Nearest Neighbors Regressor - Theory with a practical example

# %% [markdown]
# ### Introducing the database

# %% [markdown]
# The database for this example is generated randomly. Generating datasets is an important skill to have. This is the best way to explore the algorithms themelves without having to worry about encoding, standardizing, dealing with outliers and all sorts of preprocessing that comes with a real-world dataset. Another advantage of randomly generated datasets is that you have full control over the data. You are free to choose the number of features, the number of classes, the way the points are distributed, everything really!
#
# I wish you to have lots of fun with the exercise and keep experimenting!

# %% [markdown]
# ### Importing the necessary libraries

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Generating the database

# %%
inputs , target = make_regression(
    n_samples=100,
    random_state=365,
    n_features=2,
    noise =30
)

# %%
inputs
# Out:
# array([[-1.09153431, -1.2074487 ],
#        [ 1.93851932, -0.0243219 ],
#        [-0.43146216,  0.50343521],
#        [-1.25474464,  0.35457685],
#        [-1.36867866, -0.69787282],
#        [ 0.47331717,  2.18595115],
#        [ 0.18874803,  0.85224116],
#        [ 1.10785965, -1.49373321],
#        [-0.17412169, -0.28081926],
#        [ 0.76591524, -0.8561501 ],
#        [ 1.43268933,  1.74281799],
#        [-0.32656587,  1.46725775],
#        [ 0.53606684,  1.25373865],
#        [-2.93681085, -0.53816069],
#        [-0.28805149,  0.11346147],
#        [-1.16284657, -0.72779588],
#        [-0.63127704,  0.24407013],
#        [-1.52357894, -0.59373209],
#        [-0.57294652,  0.29981995],
#        [-1.18369392, -1.89946372],
#        [-0.78537956,  1.69065728],
#        [ 0.93914834, -1.00577359],
#        [ 1.20390954,  0.73040558],
#        [ 0.43830846, -1.74506089],
#        [ 0.8409464 , -0.50929269],
#        [ 0.81737553,  1.70384552],
#        [ 0.82374899,  0.96840676],
#        [ 0.63477701, -0.25843574],
#        [ 0.91784255,  1.07778288],
#        [-0.8184312 ,  0.05532964],
#        [-0.09008577, -0.09030987],
#        [ 1.01763937,  0.71317123],
#        [ 1.25936749,  0.78793743],
#        [-1.36637575,  0.14478066],
#        [-0.05965623,  1.51973051],
#        [-0.62411214,  0.32531774],
#        [ 1.57112443, -0.38327948],
#        [ 0.46428062,  1.05557598],
#        [ 1.25827458,  0.36679559],
#        [ 1.64546402, -0.77938645],
#        [ 0.21304181, -0.74663585],
#        [-0.10081143, -0.65563879],
#        [ 0.24301295,  0.34820304],
#        [ 1.73917715,  0.43047191],
#        [ 0.35265529, -1.02989486],
#        [ 0.83306385,  0.69492636],
#        [-0.95381754,  0.13371186],
#        [-0.00428237,  0.15835883],
#        [ 0.90051543, -0.6545978 ],
#        [ 1.04816035, -0.11524909],
#        [-0.1646149 ,  0.33135181],
#        [-1.45714691, -0.67358794],
#        [ 1.04195147,  0.07512296],
#        [ 0.9945953 ,  0.69499016],
#        [-0.85801065, -0.48242203],
#        [-0.27810579, -0.64058377],
#        [-2.05810558,  0.42626904],
#        [ 0.54745948, -0.0569348 ],
#        [-0.36949507, -0.75905232],
#        [ 0.8034948 , -0.14242739],
#        [-1.97257826,  1.52938353],
#        [-0.38082318, -1.77587837],
#        [ 0.63799905, -0.34465754],
#        [-2.51027611,  0.30213417],
#        [-0.76014535,  1.03942184],
#        [ 0.35722208,  0.44872185],
#        [-0.30777925,  0.80425279],
#        [-0.44771044, -0.1361512 ],
#        [ 0.79296086, -1.32581622],
#        [ 0.46088845, -2.96453627],
#        [-1.08948009, -0.49111514],
#        [-0.96645194, -0.14367903],
#        [-0.96309391, -0.4160569 ],
#        [ 1.56298289, -0.43744566],
#        [-0.90742438, -0.70297334],
#        [ 0.62062163,  0.8455433 ],
#        [-0.85431465,  0.78243903],
#        [-0.52049787, -0.37814017],
#        [ 1.15381646, -1.10191737],
#        [-2.14694755,  0.71419851],
#        [ 0.82083949, -0.75445886],
#        [ 0.33130649,  0.69330728],
#        [ 1.11952861, -0.36236584],
#        [ 1.21177272,  0.85536247],
#        [ 0.55897151,  0.4264153 ],
#        [-0.07735354,  0.39665859],
#        [-1.01916039,  0.0524724 ],
#        [ 0.16792113,  0.52350518],
#        [-0.96532552,  1.68913123],
#        [-0.70770937, -0.322613  ],
#        [ 0.67784784, -0.88760555],
#        [ 1.16626302, -0.6335548 ],
#        [ 0.20733588, -0.32695849],
#        [-0.07589737, -0.31754681],
#        [-1.27271536,  0.77700248],
#        [ 0.96792107, -0.6656934 ],
#        [ 0.61156182, -0.30585387],
#        [-0.2790599 , -1.54148919],
#        [ 0.65376963, -2.441588  ],
#        [-1.29998207,  0.03898027]])

# %%
plt.scatter(inputs[:,0],target)

# %% [markdown]
# ### Plotting the database

# %% [markdown]
# ### Creating the model

# %%
from sklearn.neighbors import KNeighborsRegressor
reg=KNeighborsRegressor(n_neighbors=2)
reg.fit(inputs,target)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %% [markdown]
# ### Predicting a sample

# %%
y=[0.6,-0.3]
y_pred=reg.predict([y])

# %%
n=reg.kneighbors([y])
n
# Out:
# (array([[0.0129593 , 0.05419436]]), array([[96, 27]], dtype=int64))

# %%
distances, indices = reg.kneighbors([y])
print(distances, indices )
# Out:
# [[0.0129593  0.05419436]] [[96 27]]

# %% [markdown]
# ### Visualizing the neighbors

# %%
plt.scatter(inputs[:, 0],target)
plt.scatter(y[0],y_pred[0])
plot_x_train=[]
plot_y_train=[]
distances, indices = reg.kneighbors([y])
plot_x_train = [inputs[i, 0] for i in indices[0]]
plot_y_train = [target[i] for i in indices[0]]

plt.scatter(plot_x_train, 
            plot_y_train, 
            s=200, facecolors='none', edgecolors='r');

# %% [markdown]
# ### Calculating the predicted value
